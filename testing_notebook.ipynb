# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

# %%
url = 'https://www.openstreetmap.org/changeset/65253865'

# %%
uClient = uReq(url)

# %%
page_html= uClient.read()

# %%
uClient.close()

# %%
page_soup = soup(page_html, "html.parser")

# %%
page_soup.body
# Out:
# <body class="map-layout">
# <header class="closed">
# <h1>
# <a class="geolink" href="/">
# <picture>
# <source srcset="/assets/osm_logo-f13314123f336d32682fddc79f2a5f0dedc894c637decede98a41587340dad19.svg" type="image/svg+xml"/>
# <img alt="OpenStreetMap logo" class="logo" src="/assets/osm_logo-ce691ac3325e0ebe119ff9087858192cc7677e50d7b77655cafc1f208161ad79.png" srcset="/assets/osm_logo-f13314123f336d32682fddc79f2a5f0dedc894c637decede98a41587340dad19.svg"/>
# </picture>
#       OpenStreetMap
#     </a>
# </h1>
# <a href="#" id="menu-icon"></a>
# <nav class="primary">
# <div class="search_forms">
# <form action="/search" class="search_form" method="GET">
# <a class="button switch_link" href="/directions" title="Find directions between two points"><img class="button" src="/assets/directions-40b86df47e67e386cb848cb45095c340f45a8283778f9205e3ae9cc1b371dc65.png"/></a>
# <input class="float" name="commit" type="submit" value="Go"/>
# <div class="query_wrapper">
# <input class="overflow" id="query" name="query" placeholder="Search" type="text"/>
# <a class="describe_location" href="#" title="Describe the current location using the search engine">Where is this?</a>
# </div>
# </form>
# <form action="/directions" class="directions_form" method="GET">
# <div class="header"><span class="icon close"></span></div>
# <div class="line">
# <img class="routing_marker" data-type="from" draggable="true" src="/assets/marker-green-0100e0bfbed70ac6d70f6d35830ad76565feecba496f9af69dcab09d178ca300.png"/>
# <span class="force_width"><input id="route_from" name="route_from" placeholder="From" type="text"/></span>
# </div>
# <div class="line">
# <img class="routing_marker" data-type="to" draggable="true" src="/assets/marker-red-b8123e4c4dfb37f82e57056da8d1caa9a865c07b8b4dd254c923cdb7ea5964b0.png"/>
# <span class="force_width"><input id="route_to" name="route_to" placeholder="To" type="text"/></span>
# </div>
# <div class="line">
# <select class="routing_engines" name="routing_engines"></select>
# <input class="routing_go" name="commit" type="submit" value="Go"/>
# </div>
# <div class="line">
# <a class="reverse_directions">Reverse Directions</a>
# </div>
# <div class="loader_copy"><div class="loader"><img src="/assets/searching-d2110831ff86cb780e0911cd005e82482bfc71a0c626b56812ece6d52db2e6e0.gif"/></div></div>
# </form>
# </div>
# <ul>
# <li class="dropdown " id="edit_tab">
# <a class="tab geolink editlink" data-editor="id" href="/edit" id="editanchor">Edit</a><a class="dropdown-toggle" data-toggle="dropdown" href="#"><b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li>
# <a class="geolink editlink" data-editor="id" href="/edit?editor=id">Edit with iD (in-browser editor)</a>
# </li>
# <li>
# <a class="geolink editlink" data-editor="potlatch2" href="/edit?editor=potlatch2">Edit with Potlatch 2 (in-browser editor)</a>
# </li>
# <li>
# <a class="geolink editlink" data-editor="remote" href="/edit?editor=remote">Edit with Remote Control (JOSM or Merkaartor)</a>
# </li>
# </ul>
# </li>
# <li class="" id="history_tab">
# <a class="tab geolink" href="/history">History</a>
# </li>
# <li class="" id="export_tab">
# <a class="tab geolink" href="/export">Export</a>
# </li>
# </ul>
# </nav>
# <nav class="secondary">
# <ul>
# <li class="compact-hide "><a href="/traces">GPS Traces</a></li>
# <li class="compact-hide "><a href="/diary">User Diaries</a></li>
# <li class="compact-hide "><a href="/copyright">Copyright</a></li>
# <li class="compact-hide "><a href="/help">Help</a></li>
# <li class="compact-hide "><a href="/about">About</a></li>
# <li class="dropdown" id="compact-secondary-nav">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">More <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class=""><a href="/traces">GPS Traces</a></li>
# <li class=""><a href="/diary">User Diaries</a></li>
# <li class=""><a href="/copyright">Copyright</a></li>
# <li class=""><a href="/help">Help</a></li>
# <li class=""><a href="/about">About</a></li>
# </ul>
# </li>
# </ul>
# <ul class="user-menu clearfix">
# <li><a href="/login?referer=%2Fchangeset%2F65253865">Log In</a></li>
# <li><a href="/user/new">Sign Up</a></li>
# </ul>
# </nav>
# </header>
# <div class="" id="content">
# <div id="sidebar">
# <div class="search_forms">
# <form action="/search" class="search_form" method="GET">
# <a class="button switch_link" href="/directions" title="Find directions between two points"><img class="button" src="/assets/directions-40b86df47e67e386cb848cb45095c340f45a8283778f9205e3ae9cc1b371dc65.png"/></a>
# <input class="float" name="commit" type="submit" value="Go"/>
# <div class="query_wrapper">
# <input autofocus="autofocus" class="overflow" id="query" name="query" placeholder="Search" type="text"/>
# <a class="describe_location" href="#" title="Describe the current location using the search engine">Where is this?</a>
# </div>
# </form>
# <form action="/directions" class="directions_form" method="GET">
# <div class="header"><span class="icon close"></span></div>
# <div class="line">
# <img class="routing_marker" data-type="from" draggable="true" src="/assets/marker-green-0100e0bfbed70ac6d70f6d35830ad76565feecba496f9af69dcab09d178ca300.png"/>
# <span class="force_width"><input id="route_from" name="route_from" placeholder="From" type="text"/></span>
# </div>
# <div class="line">
# <img class="routing_marker" data-type="to" draggable="true" src="/assets/marker-red-b8123e4c4dfb37f82e57056da8d1caa9a865c07b8b4dd254c923cdb7ea5964b0.png"/>
# <span class="force_width"><input id="route_to" name="route_to" placeholder="To" type="text"/></span>
# </div>
# <div class="line">
# <select class="routing_engines" name="routing_engines"></select>
# <input class="routing_go" name="commit" type="submit" value="Go"/>
# </div>
# <div class="line">
# <a class="reverse_directions">Reverse Directions</a>
# </div>
# <div class="loader_copy"><div class="loader"><img src="/assets/searching-d2110831ff86cb780e0911cd005e82482bfc71a0c626b56812ece6d52db2e6e0.gif"/></div></div>
# </form>
# </div>
# <div id="flash">
# </div>
# <div id="browse_status"></div>
# <div id="sidebar_loader">
# <img alt="Loading..." class="loader" src="/assets/searching-d2110831ff86cb780e0911cd005e82482bfc71a0c626b56812ece6d52db2e6e0.gif"/>
# </div>
# <div id="sidebar_content">
# <h2>
# <a class="geolink" href="/"><span class="icon close"></span></a>
#   Changeset: 65253865
# </h2>
# <div class="browse-section">
# <h4>Deleted segment of Yale Street due to bollard; Removed roundabout node and modeled a new way as a roundabout.</h4>
# <div class="details">Closed <abbr title="Created: Thu, 06 Dec 2018 23:17:07 +0000
# Closed: Thu, 06 Dec 2018 23:17:09 +0000">14 days ago</abbr> by <a href="/user/cdruck">cdruck</a></div>
# <h4>Tags</h4>
# <table class="browse-tag-list">
# <tr>
# <th class="browse-tag-k"><a href="https://wiki.openstreetmap.org/wiki/Key:changesets count?uselang=en" title="The wiki description page for the changesets_count tag">changesets_count</a></th>
# <td class="browse-tag-v">610</td>
# </tr>
# <tr>
# <th class="browse-tag-k"><a href="https://wiki.openstreetmap.org/wiki/Key:created by?uselang=en" title="The wiki description page for the created_by tag">created_by</a></th>
# <td class="browse-tag-v">iD 2.12.1</td>
# </tr>
# <tr>
# <th class="browse-tag-k">host</th>
# <td class="browse-tag-v"><a href="https://www.openstreetmap.org/edit" rel="nofollow">https://www.openstreetmap.org/edit</a></td>
# </tr>
# <tr>
# <th class="browse-tag-k"><a href="https://wiki.openstreetmap.org/wiki/Key:imagery used?uselang=en" title="The wiki description page for the imagery_used tag">imagery_used</a></th>
# <td class="browse-tag-v">Mapbox Satellite</td>
# </tr>
# <tr>
# <th class="browse-tag-k"><a href="https://wiki.openstreetmap.org/wiki/Key:locale?uselang=en" title="The wiki description page for the locale tag">locale</a></th>
# <td class="browse-tag-v">en-US</td>
# </tr>
# <tr>
# <th class="browse-tag-k"><a href="https://wiki.openstreetmap.org/wiki/Key:source?uselang=en" title="The wiki description page for the source tag">source</a></th>
# <td class="browse-tag-v">aerial imagery;streetlevel imagery</td>
# </tr>
# </table>
# <h4 class="comments-header">Discussion</h4>
# <div class="clearfix"></div>
# <div class="notice">
# <a href="/login?referer=%2Fchangeset%2F65253865">Log in to join the discussion</a>
# </div>
# <h4>
#       Ways (4)
#
#     </h4>
# <ul>
# <li><a class="way deleted" href="/way/57355545" title="">57355545, v5</a></li>
# <li><a class="way highway residential" href="/way/640150456" title="highway=residential"><bdi>College Avenue</bdi> (<bdi>640150456, v3</bdi>)</a></li>
# <li><a class="way highway residential" href="/way/597508456" title="highway=residential"><bdi>College Avenue</bdi> (<bdi>597508456, v22</bdi>)</a></li>
# <li><a class="way highway residential" href="/way/653274668" title="highway=residential">653274668, v1</a></li>
# </ul>
# <h4>
#       Nodes (1-20 of 24)
#         <span class="paginate">
#     1 <a href="/changeset/65253865?node_page=2">2</a>
# </span>
# </h4>
# <ul>
# <li><a class="node highway crossing" href="/node/6040410083" title="highway=crossing">6040410083, v3</a></li>
# <li><a class="node highway crossing" href="/node/6040410586" title="highway=crossing">6040410586, v3</a></li>
# <li><a class="node highway crossing" href="/node/6040410585" title="highway=crossing">6040410585, v3</a></li>
# <li><a class="node" href="/node/65445289" rel="nofollow" title="">65445289, v7</a></li>
# <li><a class="node" href="/node/6122456824" rel="nofollow" title="">6122456824, v1</a></li>
# <li><a class="node" href="/node/6122456823" rel="nofollow" title="">6122456823, v1</a></li>
# <li><a class="node" href="/node/6122456822" rel="nofollow" title="">6122456822, v1</a></li>
# <li><a class="node" href="/node/6122456821" rel="nofollow" title="">6122456821, v1</a></li>
# <li><a class="node" href="/node/6122456820" rel="nofollow" title="">6122456820, v1</a></li>
# <li><a class="node" href="/node/6122456819" rel="nofollow" title="">6122456819, v1</a></li>
# <li><a class="node" href="/node/6122456818" rel="nofollow" title="">6122456818, v1</a></li>
# <li><a class="node" href="/node/6122456817" rel="nofollow" title="">6122456817, v1</a></li>
# <li><a class="node" href="/node/6122456816" rel="nofollow" title="">6122456816, v1</a></li>
# <li><a class="node" href="/node/6122456815" rel="nofollow" title="">6122456815, v1</a></li>
# <li><a class="node" href="/node/6122456814" rel="nofollow" title="">6122456814, v1</a></li>
# <li><a class="node" href="/node/6122456813" rel="nofollow" title="">6122456813, v1</a></li>
# <li><a class="node" href="/node/6122456812" rel="nofollow" title="">6122456812, v1</a></li>
# <li><a class="node" href="/node/6122456811" rel="nofollow" title="">6122456811, v1</a></li>
# <li><a class="node" href="/node/6122456810" rel="nofollow" title="">6122456810, v1</a></li>
# <li><a class="node" href="/node/6122456809" rel="nofollow" title="">6122456809, v1</a></li>
# </ul>
# </div>
# <div class="secondary-actions">
# <a href="/changeset/65247059">&lt;&lt; 65247059</a>
#       ·
#     <a href="/user/cdruck/history"><bdi>cdruck</bdi></a>
#       ·
#       <a href="/changeset/65274252">65274252 &gt;&gt;</a>
# </div>
# <div class="secondary-actions">
# <a href="/api/0.6/changeset/65253865">Changeset XML</a>
#   ·
#   <a href="/api/0.6/changeset/65253865/download">osmChange XML</a>
# </div>
# </div>
# <div class="welcome">
# <h2>Welcome to OpenStreetMap!</h2>
# <div class="close-wrap"><span class="icon close"></span></div>
# <p>OpenStreetMap is a map of the world, created by people like you and free to use under an open license.</p>
# <p>Hosting is supported by <a href="https://www.ucl.ac.uk">UCL</a>, <a href="https://www.bytemark.co.uk">Bytemark Hosting</a>, and other <a href="https://hardware.openstreetmap.org/thanks/">partners</a>.
#         </p>
# <a class="button learn-more" href="/about">Learn More</a>
# <a class="button sign-up" href="/user/new">Start Mapping</a>
# </div>
# <div id="banner">
# </div>
# </div>
# <noscript>
# <div id="noscript">
# <p>You are either using a browser that does not support JavaScript, or you have disabled JavaScript.</p>
# <p>OpenStreetMap uses JavaScript for its slippy map.</p>
# </div>
# </noscript>
# <div id="map-ui">
# </div>
# <div id="map" tabindex="2">
# </div>
# <div id="attribution">
# <table>
# <tr>
# <td class="attribution_license">https://openstreetmap.org/copyright</td>
# <td class="attribution_project">https://openstreetmap.org</td>
# </tr>
# <tr>
# <td class="attribution_notice" colspan="2">Copyright OpenStreetMap and contributors, under an open license</td>
# </tr>
# </table>
# </div>
# </div>
# <noscript><p><img alt="" class="piwik" src="https://piwik.openstreetmap.org/piwik.php?idsite=1"/></p></noscript>
# </body>

# %%
containers = page_soup.find_all("ul")

# %%
0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-8f68ca8d29b9> in <module>()
# ----> 1 containers.find('li')
#
# /anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?
